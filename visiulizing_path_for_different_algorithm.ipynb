# %%
from utils.environment import Environments

# AUTO RELOAD
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Creating Environment

# %% [markdown]
# #### Input the size of the grid

# %%
size_of_matrix = int(input("Input the size - "))

# %% [markdown]
# #### Input the size of environment

# %%
no_of_environments = int(input("Enter the number of environments: "))

# %% [markdown]
# #### Creating the given no of enviorment

# %%
environments = Environments(size_of_matrix,no_of_environments)
environments_list = environments.create_multiple_environments()

# %% [markdown]
# #### visulize one of the environment

# %%
environments.visulize_random_enviroment()
